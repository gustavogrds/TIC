# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavogrds/TIC/blob/master/EDA_Titanic_questoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
titanic_url = "https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"
titanic_data = pd.read_csv(titanic_url)

# %%
# Questão 1 : Descreva o dataset

# %%
# Questào 2; encontre o passageiro mais jovem e o mais idoso

# %%
# Questão 3: Faça um gráfico da distribuição de idades dos passageiros

# %%
# Questão 4: Como os passageiros estão distribuídos por classe? Grafique.

# %%
# Questão 5: Calcule a taxa de sobreviventes por Sexo
# Out:
# Sex
# F    0.742038
# M    0.190227
# Name: Survived, dtype: float64

# %%
# Questão 6: Calcule a tarifa média pela Classe (PClass) do ticket
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.707707
# Name: Fare, dtype: float64

# %%
# Questão 7: Plote a taxa de sobrevivência pela classe (PClass) de passageiros

# %%
# Questão 8: Substitua as idades ausentes pela idade mediana e calcule a nova idade média
# Out:
# 29.471443066516347

# %%
# Questão 9: Substitua os valores "masculino" e "feminino" na coluna "Sexo" por "M" e "F"

# %%
# Pergunta 10: Selecione os passageiros que estavam na primeira classe e pagaram uma tarifa superior a US$ 100
# Out:
#      Survived  Pclass                                               Name Sex  \
# 27          0       1                      Mr. Charles Alexander Fortune   M
# 31          1       1      Mrs. William Augustus (Marie Eugenie) Spencer   F
# 87          1       1                          Miss. Mabel Helen Fortune   F
# 117         0       1                            Mr. Quigg Edmond Baxter   M
# 194         1       1                                Miss. Elise Lurette   F
# 214         1       1                             Miss. Madeleine Newell   F
# 257         1       1                                    Miss. Anna Ward   F
# 266         1       1       Mrs. William Thompson (Edith Junkins) Graham   F
# 267         1       1                              Miss. Amelia Bissette   F
# 295         0       1                        Miss. Helen Loraine Allison   F
# 297         1       1     Mrs. James (Helene DeLaudeniere Chaput) Baxter   F
# ...
