# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavogrds/TIC/blob/master/Revis%C3%A3oAn%C3%A1liseDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <head>
#   <meta name="author" content="Rogério de Oliveira">
#   <meta institution="author" content="Universidade Presbiteriana Mackenzie">
# </head>
#
# <img src="http://meusite.mackenzie.br/rogerio/mackenzie_logo/UPM.2_horizontal_vermelho.jpg" width=300, align="left">
# <!-- <h1 align=left><font size = 6, style="color:rgb(200,0,0)"> optional title </font></h1> -->

# %% [markdown]
# <H2> Revisão Análise dados </H2>

# %% [markdown]
# O Python é uma linguagem bastante poderosa e com muitos recursos. Nessa introdução de Python para Ciência de Dados vamos rever alguns os recursos mínimos necessários para fazermos Análises de Dados e construírmos modelos de Aprendizado de Máquina ao longo do curso.

# %% [markdown]
# **Imports básicos**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Conceitos importantes

# %% [markdown]
# ## Variáveis e atribuições

# %%
inteiro = 123 #inteiro
real = np.pi  #real
texto1 = '123' # texto
texto2 = 'Led Zeppelin' # texto

print(inteiro, real, texto1, texto2)

# %% [markdown]
# ## Caracteres e Valores Numéricos

# %% [markdown]
# ### Math functions

# %%
import math

# %%
print(math.pi)
print(5 % 2)
print(np.mod(55,2))

# %% [markdown]
# ### Strings
#
# Strings são estruturas **imutáveis**. Além disso note a indexação dos *slices* de strings:
#
# `str[ inicio : tamanho ]`
# ou
# `str[ inicio : fim+1 ]`

# %%
nome= "Aula de python"
print(nome[0:7])
# Out:
# Aula de

# %%
str1 ='A arte existe porque a vida não basta. – Ferreira Gullar'

print(str1.find('arte'))
print(str1.lower())
str2 = str1.replace('arte','life')
print(str2)

# %%
str1 = 'love'
str2 = 'hate'
print(str1, str2)
print(str1 == str2)
print(str1 is str2)

# %% [markdown]
# ## Print & Input

# %%
text = input('Entre com um texto: ')
print(text)
# Out:
# Entre com um texto: orlando
# orlando

# %%
numero = float(input('Entre com um número: '))
print('Seu número mais um: ', numero+1)
# Out:
# Entre com um número: 98
# Seu número mais um:  99.0

# %% [markdown]
# ## Controlando o Fluxo do Programa

# %% [markdown]
# ### If-Then-Else *
#
# Note que em Python as instruções **aninhadas** são **identadas** (*tab*), o que corresponde ao `{}` de linguagens como Java e C. Assim os comandos *aninhados* à condição ou laço do programa devem estar à direita do comando inicial da condição ou laço.

# %%
a = 1964
b = 1984

if b > a:
  print("b is greater than a")
else:
  print("a is greater than b")
# Out:
# b is greater than a

# %%
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# b is greater than a

# %% [markdown]
# ### For

# %%
for i in range(11):
  if i%2==0:
    print(i)

# %% [markdown]
# ### Funções
#
# Nossos programas não precisarão necessariamente de *criar* funções, mas é comum a chamada de funções e o seu uso pode permitir deixar o código mais modular e enxuto.

# %%
def mymax(a,b):
  if a > b:
    return a
  else:
    return b

mymax(1984,1964)
# Out:
# 1984

# %% [markdown]
# ## Estruturas de Dados
#
# Estruturas de dados como Lists, Sets, Tuples, Sequencies e Dictionary desempenham um papel fundamental tanto para programação em geral como para aplicações mais avançadas como a análise de dados.

# %% [markdown]
# Existem quatro tipos de dados de coleções em Python:
#
# - Lista (**list**) é uma coleção que é ordenada e mutável. Permite membros duplicados.
# - Tupla (**tuple**) é uma coleção que é ordenada e imutável. Permite membros duplicados.
# - Conjunto (**set**) é uma coleção não ordenada e não indexada. Nenhum membro duplicado.
# - Dicionário (**dictionary**) é uma coleção desordenada, mutável e indexada. Nenhum membro duplicado.
#
# Vamos nos deter aqui apenas nas estruturas de listas e tuplas que terão mais utilidade para os nossos propósitos

# %% [markdown]
# ## List *
#
# Lista (**list**) é uma coleção que é **ordenada** e **mutável**. Permite membros **duplicados**. Associada a lista você encontra uma série métodos que implementam funções úteis para esses objetos.

# %%
mylist = ['A', 'B', 'C', 'A', 'B']

len(mylist)
mylist.count('B')
mylist.append('D')
mylist.sort()
mylist.insert(1,'X')
mylist.remove('B') # somente o primeiro elemento
mylist[1] = 'ZZ'
# del mylist[0:1]

# %% [markdown]
# ## Percorrendo uma lista *
#
# Existem basicamente duas forma de percorrer uma lista.
#
# * **Por índice**, empregue quando precisar do índice (posição) ou alterar os elementos
# * **Por iterador**, empregue apenas para recuperar (ler) os elementos

# %%
mylist = ['A', 'B', 'C', 'A', 'B']

for i in range(len(mylist)):
    print(i, mylist[i])

# %% [markdown]
# ## Dictionary
#
# Dicionário (**dictionary**) é uma coleção desordenada, mutável e indexada. Nenhum membro duplicado. Você já teve algum contato com uma estrutura de dados `JSON` essa uma estrutura bastante semelhante em Python.

# %%
mydict = {'Beatriz':1978, 'Aline':1987, 'Adriana':1984, 'Daniel':1996}
print(mydict.keys())
print(mydict['Adriana'])

# %% [markdown]
# ## Percorrendo um Dicionário *

# %%
for item in mydict:
    print(item, mydict[item])
# Out:
# Beatriz 1978
# Aline 1987
# Adriana 1984
# Daniel 1996

# %% [markdown]
# ## Numpy *
#
# Talvez você não tenha notado. Mas o Python não vetores ou matrizes. A biblioteca `numpy` implementa então essas funções.
#
# Para nossos propósitos será suficiente o uso de vetores e algumas poucas funções do `numpy`, mas aplicações mais sofisticadas podem requerem um domínio maior dessa biblioteca numérica.
#
# Os vetores do `numpy` operam como listas indexadas e você pode empregar os mesmos códigos de listas para **percorrer** e **popular** vetores `numpy`.

# %%
import numpy as np
np.random.seed(1984) # semente de geração aleatória
x = np.array(np.random.randint(low=1, high=6, size=10))
print(x)

x = np.array([1,2,3])
np.mean(x)
np.sum(x)
np.power(x,2)

# %% [markdown]
# # Pandas

# %% [markdown]
# O `Pandas` é uma API (biblioteca) Python para manipulação e análise de dados orientada a colunas. Ela permite organizar dados em dois tipos de estruturas, Séries e DataFrames e operar seleções e transformações sobre essas coleções de dados.

# %% [markdown]
# Comece vendo um resumo dos comandos Pandas aqui [Pandas Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf).
#
#
# * **DataFrame**: você pode imaginar como uma tabela de dados relacionais, com linhas e colunas nomeadas, como no Excel ou SQL.
# * **Series**: é uma única coluna de dados, e o DataFrame contém um ou mais Series com um nome para cada uma delas.
#
# O quadro de dados é uma abstração comumente usada para manipulação de dados. Existem implementações similares em faísca e R .

# %% [markdown]
# Você pode ler e gravar dados de diferentes fontes como arquivos .csv, .json, .xlsx e arquivos de bancos de dados sql, Mongo etc.

# %% [markdown]
# | Format        | Read           | Save          |
# | ------------- |:--------------:| ----------------:|
# | csv           | `pd.read_csv()`  |`df.to_csv()`     |
# | json          | `pd.read_json()` |`df.to_json()`    |
# | xlsx          | `pd.read_excel()`|`df.to_excel()`   |
# | hdf           | `pd.read_hdf()`  |`df.to_hdf()`     |
# | sql           | `pd.read_sql()`  |`df.to_sql()`     |

# %% [markdown]
# Vamos discutir funções e seleção de dados usando como exemplo a base de dados Titanic.

# %% [markdown]
# ## Exemplo Titanic

# %%
import pandas as pd

df = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# Informações das variáveis:
#
# - Survived: Indica se o passageiro sobreviveu (1) ou não (0) ao naufrágio.
# - Pclass: Classe do bilhete, representando a classe do passageiro (1ª, 2ª ou 3ª classe).
# - Name: Nome do passageiro.
# - Sex: Gênero do passageiro (Masculino ou Feminino).
# - Age: Idade do passageiro.
# - Siblings/Spouses: Número de irmãos ou cônjuges a bordo.
# - Parents/Children: Número de pais ou filhos a bordo.
# - Fare: Valor pago pelo bilhete.

# %% [markdown]
# ### Explorando os dados
#
# É importante na primeira análise extrair informações sobre a estrutura dos dados, isto é, verificar o tipo de variáveis, número de linhas, colunas, dados faltantes, etc.

# %%
# Funções interessantes

df.head()
df.tail()
df.columns
df.shape
df.info()

# %% [markdown]
# A função `describe()` do pandas é uma ferramenta muito útil para obter um resumo estatístico de um DataFrame.

# %%
df.describe()

# %%
df.describe(include="all")

# %% [markdown]
# ### Seleção de Colunas, Linhas e Linhas e Colunas
#
# <img src="https://pandas.pydata.org/docs/_images/03_subset_columns.svg" width=320, align="center">
# <img src="https://pandas.pydata.org/docs/_images/03_subset_rows.svg" width=320, align="center">
# <img src="https://pandas.pydata.org/docs/_images/03_subset_columns_rows.svg" width=320, align="center">

# %% [markdown]
# **Selecionando colunas**
#
# No pandas, você pode selecionar colunas de um DataFrame de várias maneiras diferentes. Aqui estão as duas formas mais comuns de fazer isso:

# %%
# As duas opções retornam o mesmo resultado.
df.Age  # Opção 1
df['Age'] # Opção 2

# %% [markdown]
# Se você quiser calcular estatísticas específicas pode usar as seguintes funções:  `mean()` para a média, `std()` para o desvio padrão, `min()` e `max()` para os valores mínimo e máximo, etc.

# %%
# valores descritivos da variável "Age"

print(df.Age.max())  # valor máximo
print(df.Age.min())  # valor mínimo
print(df.Age.mean()) # média
print(df.Age.std())  # desvio padrão
print(df.Age.quantile()) # Exibe a mediana
print(df.Age.quantile([0, 0.25, 0.5, 0.9])) # exibindo diferentes percentis

# %%
# print mais sofisticado
print(f'Idade média: {df.Age.mean() :.3f} ')
# Out:
# Idade média: 29.471

# %% [markdown]
# **Variáveis categóricas (não numéricas)**
#
# Variáveis categóricas são aquelas que representam categorias ou grupos distintos, em vez de valores numéricos contínuos. Elas são comuns em dados que envolvem características não numéricas, como gênero, cor, tipo de animal, estado civil, etc.

# %%
sexo=df.Sex.to_list() # Converter Sex em uma lista
sexo.count('male')    # Contar o número de vezes que aparece "male"
# Out:
# 573

# %%
# Funções úteis

df.Sex.value_counts() # valores diferentes e suas quantidades
df.Sex.unique()       # Mostra os valores únicos
df.Sex.nunique()      # Número de valores únicos
# Out:
# male      573
# female    314
# Name: Sex, dtype: int64
# ['male' 'female']
# 2

# %% [markdown]
# **Selecionando várias colunas**
#
# Para selecionar várias colunas em um DataFrame do pandas, você pode passar uma lista com os nomes das colunas que deseja selecionar. Lembre-se de que, ao selecionar várias colunas, o resultado será um novo DataFrame contendo apenas as colunas selecionadas.

# %%
# Selecionando várias colunas

df[["Name",	"Sex",	"Age"]]
# Out:
#                                                   Name     Sex   Age
# 0                               Mr. Owen Harris Braund    male  22.0
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2                                Miss. Laina Heikkinen  female  26.0
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4                              Mr. William Henry Allen    male  35.0
# ..                                                 ...     ...   ...
# 882                               Rev. Juozas Montvila    male  27.0
# 883                        Miss. Margaret Edith Graham  female  19.0
# 884                     Miss. Catherine Helen Johnston  female   7.0
# 885                               Mr. Karl Howell Behr    male  26.0
# 886                                 Mr. Patrick Dooley    male  32.0
#
# [887 rows x 3 columns]

# %%
# Funções úteis
df.dropna() # Remove missing values

# %%
df.isna()  # Detect missing values

# %%
df.nsmallest(5,'Age')  # Exibe os n menores valores segundo certa determinada variável
# Out:
#      Survived  Pclass                            Name     Sex   Age  \
# 799         1       3  Master. Assad Alexander Thomas    male  0.42
# 751         1       2        Master. Viljo Hamalainen    male  0.67
# 466         1       3    Miss. Helene Barbara Baclini  female  0.75
# 641         1       3           Miss. Eugenie Baclini  female  0.75
# 77          1       2    Master. Alden Gates Caldwell    male  0.83
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 799                        0                        1   8.5167
# 751                        1                        1  14.5000
# 466                        2                        1  19.2583
# 641                        2                        1  19.2583
# 77                         0                        2  29.0000

# %% [markdown]
# **Selecionando linhas**
#
# Para selecionar linhas em um DataFrame do pandas podemos usar os colchetes com base em critérios específicos:

# %%
# Selecionando linhas
df[df.Sex=="male"]
# Out:
#      Survived  Pclass                           Name   Sex   Age  \
# 0           0       3         Mr. Owen Harris Braund  male  22.0
# 4           0       3        Mr. William Henry Allen  male  35.0
# 5           0       3                Mr. James Moran  male  27.0
# 6           0       1         Mr. Timothy J McCarthy  male  54.0
# 7           0       3  Master. Gosta Leonard Palsson  male   2.0
# ..        ...     ...                            ...   ...   ...
# 879         0       2   Mr. Frederick James Banfield  male  28.0
# 880         0       3          Mr. Henry Jr Sutehall  male  25.0
# 882         0       2           Rev. Juozas Montvila  male  27.0
# 885         1       1           Mr. Karl Howell Behr  male  26.0
# 886         0       3             Mr. Patrick Dooley  male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0                          1                        0   7.2500
# ...

# %% [markdown]
# Para combinar critérios de seleção você pode empregar os operadores lógicos & (AND), '|' (OR) ou '!' (NOT), sendo necessário a inclusão de parênteses nas seleções.

# %%
df[(df.Sex=="male") & (df.Age>70)]
# Out:
#      Survived  Pclass                                 Name   Sex   Age  \
# 95          0       1             Mr. George B Goldschmidt  male  71.0
# 115         0       3                  Mr. Patrick Connors  male  70.5
# 490         0       1               Mr. Ramon Artagaveytia  male  71.0
# 627         1       1  Mr. Algernon Henry Wilson Barkworth  male  80.0
# 847         0       3                   Mr. Johan Svensson  male  74.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 95                         0                        0  34.6542
# 115                        0                        0   7.7500
# 490                        0                        0  49.5042
# 627                        0                        0  30.0000
# 847                        0                        0   7.7750

# %%
df[(df.Pclass==3) | (df.Pclass==2)]
# Out:
#      Survived  Pclass                                 Name     Sex   Age  \
# 0           0       3               Mr. Owen Harris Braund    male  22.0
# 2           1       3                Miss. Laina Heikkinen  female  26.0
# 4           0       3              Mr. William Henry Allen    male  35.0
# 5           0       3                      Mr. James Moran    male  27.0
# 7           0       3        Master. Gosta Leonard Palsson    male   2.0
# ..        ...     ...                                  ...     ...   ...
# 880         0       3                Mr. Henry Jr Sutehall    male  25.0
# 881         0       3  Mrs. William (Margaret Norton) Rice  female  39.0
# 882         0       2                 Rev. Juozas Montvila    male  27.0
# 884         0       3       Miss. Catherine Helen Johnston  female   7.0
# 886         0       3                   Mr. Patrick Dooley    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
# **Selecionando colunas e linhas**
#
# Podemos selecionar primeiro as linhas (segundo uma condição) e depois selecionar as colunas desejadas.

# %%
df[df.Sex=="male"].Fare
# Out:
# 0       7.2500
# 4       8.0500
# 5       8.4583
# 6      51.8625
# 7      21.0750
#         ...
# 879    10.5000
# 880     7.0500
# 882    13.0000
# 885    30.0000
# 886     7.7500
# Name: Fare, Length: 573, dtype: float64

# %%
df[df.Sex=="male"][["Fare"]]
# Out:
#         Fare
# 0     7.2500
# 4     8.0500
# 5     8.4583
# 6    51.8625
# 7    21.0750
# ..       ...
# 879  10.5000
# 880   7.0500
# 882  13.0000
# 885  30.0000
# 886   7.7500
#
# [573 rows x 1 columns]

# %%
df[df.Sex=="male"][["Fare","Survived","Pclass"]]
# Out:
#         Fare  Survived  Pclass
# 0     7.2500         0       3
# 4     8.0500         0       3
# 5     8.4583         0       3
# 6    51.8625         0       1
# 7    21.0750         0       3
# ..       ...       ...     ...
# 879  10.5000         0       2
# 880   7.0500         0       3
# 882  13.0000         0       2
# 885  30.0000         1       1
# 886   7.7500         0       3
#
# [573 rows x 3 columns]

# %% [markdown]
# ### Questão 1.
#
# Selecionar informações dos passageiros do sexo masculino da terceira classe, incluindo o valor pago pelo bilhete e se sobreviveram ou não

# %%
df[(df.Sex=="male")& (df.Pclass==3)][["Fare","Survived"]]
# Out:
#         Fare  Survived
# 0     7.2500         0
# 4     8.0500         0
# 5     8.4583         0
# 7    21.0750         0
# 12    8.0500         0
# ..       ...       ...
# 873   7.8958         0
# 874   7.8958         0
# 877   7.8958         0
# 880   7.0500         0
# 886   7.7500         0
#
# [343 rows x 2 columns]

# %% [markdown]
# ### Questão 2
# Usando a função 'describe', buscar insights.

# %%
df[(df.Sex=="male")& (df.Pclass==3)][["Fare","Survived"]].describe()
# Out:
#              Fare    Survived
# count  343.000000  343.000000
# mean    12.695466    0.137026
# std     11.740102    0.344377
# min      0.000000    0.000000
# 25%      7.750000    0.000000
# 50%      7.925000    0.000000
# 75%     10.008300    0.000000
# max     69.550000    1.000000

# %% [markdown]
# ### Questão 3
#
# Fazendo um gráfico usando Pandas (Você já sabe que é muito mais fácil usando a biblioteca `matplotlib`).

# %%
df2=df[["Sex"]].value_counts().reset_index()
df2.columns = ['Sex', 'Count']

df2.head()
# Out:
#       Sex  Count
# 0    male    573
# 1  female    314

# %%
df2.plot(kind='bar', x='Sex', y="Count")
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# # Exercício
#
# Explore muito mais a base de dados de Titanic. Encontre pelo menos 5 fatos interessantes relacionando as variáveis disponíveis na base de dados.

# %%
# Código 1

# %%
# Código 2

# %%
# Código 3
